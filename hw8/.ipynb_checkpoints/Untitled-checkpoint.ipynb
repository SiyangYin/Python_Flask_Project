# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv("IMDB-Movie-Data.csv")#.rename(columns={"Rank":"Id"})
df1 = df1.dropna()
df1 = df1.drop(["Rank","Title","Genre","Description","Year"],1)
# df1.insert(0,"Id",range(1,df1.shape[0]+1))
# df
# list_of_dict1 = df1.to_dict("records")
# list_of_dict1

# df2 = pd.read_csv("itunes_data.csv")#.rename(columns={"Rank":"Id"})
# df2 = df2.dropna(axis=1)
# df2
# df2 = df2.drop("Rank",1)
# df2.insert(0,"Id",range(1,df2.shape[0]+1))
# # df
# list_of_dict2 = df2.to_dict("records")[:50]
# list_of_dict2

df3 = pd.read_csv("MovieGenre.csv", encoding='gbk')#.rename(columns={"Rank":"Id"})
df3 = df3.dropna()
df3 = df3.drop('IMDB Score',1)
# df3 = df3.drop("Rank",1)
# df3.insert(0,"Id",range(1,df3.shape[0]+1))
# df
list_of_dict3 = df3.to_dict("records")
# list_of_dict3

df4 = pd.read_csv("Hydra-Movie-Scrape.csv", encoding='gbk')#.rename(columns={"Rank":"Id"})
df4 = df4.dropna()
# df4
# df4 = df4.drop("Rank",1)
# df4.insert(0,"Id",range(1,df4.shape[0]+1))
# df
list_of_dict4 = df4.to_dict("records")
# list_of_dict4

df = pd.concat([df3,df1,df4['Summary']],axis=1)
df = df.drop([45,50,52,53])
df = df.dropna()
# df[:50]
df.insert(0,"Id",range(1,df.shape[0]+1))
list_of_dict = df.to_dict("records")[:50]
list_of_dict
# Out:
#       imdbId                           Imdb Link  \
# 0   114709.0  http://www.imdb.com/title/tt114709
# 1   113497.0  http://www.imdb.com/title/tt113497
# 2   113228.0  http://www.imdb.com/title/tt113228
# 3   114885.0  http://www.imdb.com/title/tt114885
# 4   113041.0  http://www.imdb.com/title/tt113041
# 5   113277.0  http://www.imdb.com/title/tt113277
# 6   114319.0  http://www.imdb.com/title/tt114319
# 8   114576.0  http://www.imdb.com/title/tt114576
# 9   113189.0  http://www.imdb.com/title/tt113189
# 10  112346.0  http://www.imdb.com/title/tt112346
# 11  112896.0  http://www.imdb.com/title/tt112896
# 13  113987.0  http://www.imdb.com/title/tt113987
# 14  112760.0  http://www.imdb.com/title/tt112760
# 15  112641.0  http://www.imdb.com/title/tt112641
# 16  114388.0  http://www.imdb.com/title/tt114388
# 17  113101.0  http://www.imdb.com/title/tt113101
# 19  113845.0  http://www.imdb.com/title/tt113845
# 20  113161.0  http://www.imdb.com/title/tt113161
# ...

# %%
df3 = pd.read_csv("MovieGenre.csv", encoding='gbk')#.rename(columns={"Rank":"Id"})
df3 = df3.dropna()
# df3
# df3 = df3.drop("Rank",1)
df3.insert(0,"Id",range(1,df3.shape[0]+1))
# df
list_of_dict3 = df3.to_dict("records")[:50]
list_of_dict3
# Out:
# [{'Id': 1,
#   'imdbId': 114709,
#   'Imdb Link': 'http://www.imdb.com/title/tt114709',
#   'Title': 'Toy Story (1995)',
#   'IMDB Score': 8.3,
#   'Genre': 'Animation|Adventure|Comedy',
#   'Poster': 'https://images-na.ssl-images-amazon.com/images/M/MV5BMDU2ZWJlMjktMTRhMy00ZTA5LWEzNDgtYmNmZTEwZTViZWJkXkEyXkFqcGdeQXVyNDQ2OTk4MzI@._V1_UX182_CR0,0,182,268_AL_.jpg'},
#  {'Id': 2,
#   'imdbId': 113497,
#   'Imdb Link': 'http://www.imdb.com/title/tt113497',
#   'Title': 'Jumanji (1995)',
#   'IMDB Score': 6.9,
#   'Genre': 'Action|Adventure|Family',
#   'Poster': 'https://images-na.ssl-images-amazon.com/images/M/MV5BZTk2ZmUwYmEtNTcwZS00YmMyLWFkYjMtNTRmZDA3YWExMjc2XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_UY268_CR10,0,182,268_AL_.jpg'},
#  {'Id': 3,
#   'imdbId': 113228,
#   'Imdb Link': 'http://www.imdb.com/title/tt113228',
#   'Title': 'Grumpier Old Men (1995)',
#   'IMDB Score': 6.6,
#   'Genre': 'Comedy|Romance',
# ...

# %%
df1 = pd.read_csv("IMDB-Movie-Data.csv")#.rename(columns={"Rank":"Id"})
df1 = df1.dropna()
df1 = df1.drop("Rank",1)[:50]
df1.insert(0,"Id",range(1,df1.shape[0]+1))
# df
list_of_dict1 = df1.to_dict("records")
list_of_dict1
# Out:
# [{'Id': 1,
#   'Title': 'Guardians of the Galaxy',
#   'Genre': 'Action,Adventure,Sci-Fi',
#   'Description': 'A group of intergalactic criminals are forced to work together to stop a fanatical warrior from taking control of the universe.',
#   'Director': 'James Gunn',
#   'Actors': 'Chris Pratt, Vin Diesel, Bradley Cooper, Zoe Saldana',
#   'Year': 2014,
#   'Runtime (Minutes)': 121,
#   'Rating': 8.1,
#   'Votes': 757074,
#   'Revenue (Millions)': 333.13,
#   'Metascore': 76.0},
#  {'Id': 2,
#   'Title': 'Prometheus',
#   'Genre': 'Adventure,Mystery,Sci-Fi',
#   'Description': 'Following clues to the origin of mankind, a team finds a structure on a distant moon, but they soon realize they are not alone.',
#   'Director': 'Ridley Scott',
#   'Actors': 'Noomi Rapace, Logan Marshall-Green, Michael Fassbender, Charlize Theron',
#   'Year': 2012,
#   'Runtime (Minutes)': 124,
#   'Rating': 7.0,
#   'Votes': 485820,
#   'Revenue (Millions)': 126.46,
#   'Metascore': 65.0},
#  {'Id': 3,
# ...

# %%
df4 = pd.read_csv("Hydra-Movie-Scrape.csv", encoding='gbk')#.rename(columns={"Rank":"Id"})
df4 = df4.dropna()
# df4
# df4 = df4.drop("Rank",1)
df4.insert(0,"Id",range(1,df4.shape[0]+1))
# df
list_of_dict4 = df4.to_dict("records")[:50]
list_of_dict4
# Out:
# [{'Id': 1,
#   'Title': 'Patton Oswalt: Annihilation',
#   'Year': 2017,
#   'Summary': 'Patton Oswald, despite a personal tragedy, produces his best standup yet. Focusing on the tribulations of the Trump era and life after the loss of a loved one, Patton Oswald continues his journey to contribute joy to the world.',
#   'Short Summary': 'Patton Oswalt, despite a personal tragedy, produces his best standup yet. Focusing on the tribulations of the Trump era and life after the loss of a loved one, Oswalt continues his journey to contribute joy to the world.',
#   'IMDB ID': 'tt7026230',
#   'Runtime': 66,
#   'YouTube Trailer': '4hZi5QaMBFc',
#   'Rating': 7.4,
#   'Movie Poster': 'https://hydramovies.com/wp-content/uploads/2018/04/Patton-Oswalt-Annihilation-Movie-Poster.jpg',
#   'Director': 'Bobcat Goldthwait',
#   'Writers': 'Patton Oswalt',
#   'Cast': 'Patton Oswalt'},
#  {'Id': 2,
#   'Title': 'New York Doll',
#   'Year': 2005,
# ...
